# %% [markdown]
# # How to use the Database

# %% [markdown]
# The first thing we need to do is retrieve the remove DB to our local hdf5 copy. This can be done using the script in $ICDIR/Database/download.py. It should be run again anytime we have db updates.

# %%
! python ../../Database/download.py

# %% [markdown]
# Having done that, we can use the interface to access de data. So far we only have one table with information on PMTs which we will get as Pandas dataframe:

# %%
from Database import loadDB
loadDB.DataPMT()
# Out:
#     sensorID  channel pmtid  active           x           y  deconvClean  \
# 0          0        0  PMT1       1  -23.941401   65.778503     0.000003
# 1          1       18  PMT3       1  -44.995098  -53.623100     0.000003
# 2          2        1  PMT2       1   68.936501  -12.155400     0.000003
# 3          3       19  PMT4       1    0.000000  185.000000     0.000003
# 4          4       27  PMTC       1 -118.916000  141.718002     0.000003
# 5          5       26  PMTB       1 -182.188995   32.124901     0.000004
# 6          6        9  PMTA       1 -160.214996  -92.500000     0.000003
# 7          7        8  PMT9       1  -63.273701 -173.843002     0.000003
# 8          8       23  PMT8       1   63.273701 -173.843002     0.000003
# 9          9       22  PMT7       1  160.214996  -92.500000     0.000003
# 10        10        5  PMT6       1  182.188995   32.124901     0.000003
# 11        11        4  PMT5       1  118.916000  141.718002     0.000003
#
#     deconvCoeff  noise_rms
# 0      0.001632     0.7068
# 1      0.001610     0.8744
# 2      0.001611     0.7213
# 3      0.001599     0.7624
# 4      0.001567     0.7921
# 5      0.001650     0.8660
# 6      0.001593     0.7062
# 7      0.001612     0.7278
# 8      0.001601     0.7303
# 9      0.001593     0.7160
# 10     0.001575     0.7323
# 11     0.001596     0.7206
