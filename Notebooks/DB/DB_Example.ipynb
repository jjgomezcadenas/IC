# %% [markdown]
# # How to use the Database

# %% [markdown]
# The first thing we need to do is retrieve the remove DB to our local hdf5 copy. This can be done using the script in $ICDIR/Database/download.py. It should be run again anytime we have db updates.

# %%
! python ../../Database/download.py

# %% [markdown]
# Having done that, we can use the interface to access de data. So far we only have one table with information on PMTs which we will get as Pandas dataframe:

# %%
from Database import loadDB
loadDB.DataPMT()
# Out:
#     sensorID  channel  active           x           y     coeff  adc_to_pes  \
# 0          0        0       1  -23.941401   65.778503  0.001652   19.464001
# 1          1       18       1  -44.995098  -53.623100  0.001632   18.762199
# 2          2        1       1   68.936501  -12.155400  0.001631   18.850100
# 3          3       19       1    0.000000  185.000000  0.001629   19.644899
# 4          4       27       1 -118.916000  141.718002  0.001582   19.470800
# 5          5       26       1 -182.188995   32.124901  0.001595   19.383900
# 6          6       13       1 -160.214996  -92.500000  0.000000   20.190399
# 7          7       12       1  -63.273701 -173.843002  0.000000   18.423300
# 8          8       23       1   63.273701 -173.843002  0.001627   18.935900
# 9          9       22       1  160.214996  -92.500000  0.001621   18.522301
# 10        10        5       1  182.188995   32.124901  0.001601   18.805901
# 11        11        4       1  118.916000  141.718002  0.001611   18.734600
#
#     noise_rms
# 0      0.7134
# 1      0.9578
# 2      0.7090
# 3      0.7726
# 4      0.7348
# 5      0.7908
# 6      0.7045
# 7      0.7362
# 8      0.7339
# 9      0.7404
# 10     0.7299
# 11     0.7217
