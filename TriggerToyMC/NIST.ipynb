# %% [markdown]
# Data taken from http://physics.nist.gov/PhysRefData/Xcom/html/xcom1.html
# More information: http://physics.nist.gov/PhysRefData/XrayMassCoef/chap3.html

# %%
import pandas as pd
import Core.system_of_units as units

# %%
data = pd.read_table('xe.txt',index_col=False)
data['Photoelectric'] = data['Photoelectric'] * units.g/units.cm2
data['Compton'] = data['Compton'] * units.g/units.cm2
data['Energy'] = data['Energy'] * units.MeV

# %%
data
# Out:
#            Energy       Compton  Photoelectric
# 0        0.001000  2.756873e+17   5.868888e+23
# 1        0.001072  3.101405e+17   5.076217e+23
# 2        0.001149  3.484009e+17   4.389027e+23
# 3        0.001149  3.484009e+17   4.577521e+23
# 4        0.001500  5.319012e+17   2.544662e+23
# 5        0.002000  8.020336e+17   1.298233e+23
# 6        0.003000  1.325072e+18   4.815322e+22
# 7        0.004000  1.793809e+18   2.328082e+22
# 8        0.004782  2.111502e+18   1.471123e+22
# 9        0.004782  2.111502e+18   4.300398e+22
# 10       0.005000  2.193889e+18   3.959612e+22
# 11       0.005104  2.232587e+18   3.741783e+22
# 12       0.005104  2.232587e+18   5.076217e+22
# 13       0.005275  2.295002e+18   4.690492e+22
# 14       0.005453  2.357417e+18   4.334726e+22
# 15       0.005453  2.357417e+18   5.004440e+22
# 16       0.006000  2.540917e+18   3.950874e+22
# 17       0.008000  3.137605e+18   1.871204e+22
# 18       0.010000  3.650033e+18   1.037338e+22
# ...

# %%
#energy and density from http://next.ific.uv.es:8888/nextsw/nexus/blob/master/source/materials/XenonGasProperties.cc
