# %% [markdown]
# # Na22 - PMaps and Panda runs from wfs

# %%
import time
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
print("Run {} at {}.".format(time.strftime("%d/%m/%Y"),time.strftime("%H:%M:%S")))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Run 16/12/2016 at 13:37:55.

# %%
from Database import loadDB as db
from Ana.NaXRays import tamara as tam

# %%
pmaps, pan = tam.run(tam.ifiles, tam.ofile, -1)
# Out:
# reading  /Users/hernando/Investigacion/NEXT/Data/NEWStar/Na/r2948/run_2948_0_RWF.h5
# n events read  1320
# n created pmaps  1320
# n pmaps 1320
# selected pmaps  851
# average s1 1.0
# average s2 1.89035449299
# entries 1213
# reading  /Users/hernando/Investigacion/NEXT/Data/NEWStar/Na/r2948/run_2948_1_RWF.h5
# n events read  1320
# n created pmaps  1320
# n pmaps 1320
# selected pmaps  861
# average s1 1.0
# average s2 1.93481717011
# entries 1258
# reading  /Users/hernando/Investigacion/NEXT/Data/NEWStar/Na/r2948/run_2948_2_RWF.h5
# n events read  1320
# n created pmaps  1320
# n pmaps 1320
# selected pmaps  890
# average s1 1.0
# average s2 1.94793261868
# entries 1306
# reading  /Users/hernando/Investigacion/NEXT/Data/NEWStar/Na/r2948/run_2948_3_RWF.h5
# n events read  1320
# n created pmaps  1320
# n pmaps 1320
# selected pmaps  837
# average s1 1.0
# average s2 1.89672131148
# entries 1220
# reading  /Users/hernando/Investigacion/NEXT/Data/NEWStar/Na/r2948/run_2948_4_RWF.h5
# ...

# %%
import naPlots as naplt

# %%
fig = naplt.plot_pmap_wfs(pmaps[0])

# %%
sipmdb = db.DataSiPM()
xs = sipmdb['X']
ys = sipmdb['Y']

# %%
fig = naplt.plot_peak(pmaps[0].peaks[2], xs, ys, q0=-100, bary=False)

# %%
fig = naplt.plot_pan(pan, labels=['t0', 't0wd', 't0cat', 't0ano', 't0icat'])

# %%
fig = naplt.plot_pan(pan, labels=['t', 'twd', 'tcat', 'tano', 'ticat'])

# %%
plt.scatter(pan['x'], pan['y']);
